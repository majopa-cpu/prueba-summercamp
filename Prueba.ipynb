# %% [markdown]
# <a href="https://colab.research.google.com/github/majopa-cpu/prueba-summercamp/blob/main/Prueba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hola que tal")
# Out:
# Hola que tal

# %%
jugador = "Kirby"
print(Jugador,"gano la partida")
jugador2= "R.O.B"
print(jugador2,"ha perdido una vida")
# Out:
# Kirby gano la partida
# R.O.B ha perdido una vida
